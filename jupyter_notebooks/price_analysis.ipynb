# %%
import pandas as pd
import json
import numpy as np
import altair as alt

db_item = pd.read_csv('C:/Users/juanx/Downloads/forWeb/db_item_clean.csv')
db_item

# Cast date_quote_s and date_quote_e to date type and format yyyymm
# Out:
#       item_id                     description  date_quote_s  date_quote_e  \
# 0      210101    LARGE LOAF-WHITE-SLICED-800G        198802        200401
# 1      210102  LARGE LOAF-WHITE-UNSLICED-800G        198802        202511
# 2      210105   LARGE WHOLEMEAL LOAF-UNSLICED        198802        200301
# 3      210106     SIX BREAD ROLLS-WHITE/BROWN        198802        202511
# 4      210107     BROWN LOAF,400G,SLICED-GRAN        198903        200401
# ...       ...                             ...           ...           ...
# 1382   640233       LEISURE CENTRE MEMBERSHIP        200302        201201
# 1383   640240         LIVERY CHARGES PER WEEK        200802        202511
# 1384   640243   SOFT PLAY SESSION TIME PERIOD        201802        202511
# 1385   640244           CLIMBING WALL SESSION        202202        202511
# 1386   640406             HOTEL 1 NIGHT PRICE        200502        202511
#
#       n_obs
# 0     36039
# 1     56987
# 2     27161
# 3     67610
# ...

# %%
db_prices = pd.read_csv('C:/Users/juanx/Downloads/forWeb/db_prices.csv')
db_prices
# Out:
#           quote_date  shop_code  item_id_raw  region   price indicator_box  \
# 0           200206.0        9.0       210101     3.0    0.69             Q
# 1           199901.0      937.0       210101    13.0    0.45           NaN
# 2           199211.0       16.0       210101     9.0    0.54           NaN
# 3           199606.0      187.0       210101     8.0    0.77           NaN
# 4           200204.0      807.0       210101     8.0    0.39             Q
# ...              ...        ...          ...     ...     ...           ...
# 48500746    202312.0    16599.0       640406     3.0   60.00           NaN
# 48500747    201110.0     5262.0       640406     4.0  170.00           NaN
# 48500748    200902.0      465.0       640406     5.0   60.00           NaN
# 48500749    201712.0      654.0       640406     2.0  305.00           NaN
# 48500750    201405.0      542.0       640406     2.0   60.00           NaN
#
#           item_id
# 0          210101
# 1          210101
# ...

# %%
db_itemWeights = pd.read_csv('C:/Users/juanx/Downloads/forWeb/db_itemWeights.csv')
db_itemWeights
# Out:
#         quote_date   item_id  coicop_weight  dup
# 0         199602.0  210101.0           2.75    0
# 1         199603.0  210101.0           2.75    0
# 2         199604.0  210101.0           2.75    0
# 3         199605.0  210101.0           2.75    0
# 4         199606.0  210101.0           2.75    0
# ...            ...       ...            ...  ...
# 197327    202011.0  640407.0          10.80    0
# 197328    202012.0  640407.0          10.80    0
# 197329    202101.0  640407.0          10.80    0
# 197330    202102.0  640407.0           8.10    0
# 197331         NaN       NaN            NaN    0
#
# [197332 rows x 4 columns]

# %%
db_region = pd.read_csv('C:/Users/juanx/Downloads/forWeb/db_region.csv')
db_region
# Out:
#     region_n               region_s              region           country  \
# 0          1  Catalogue collections           Catalogue               NaN
# 1          2                 London              London           England
# 2          3             South East          South East           England
# 3          4             South West          South West           England
# 4          5            East Anglia         East Anglia           England
# 5          6          East Midlands       East Midlands           England
# 6          7          West Midlands       West Midlands           England
# 7          8     Yorkshire & Humber  Yorkshire & Humber           England
# 8          9             North West          North West           England
# 9         10                  North               North           England
# 10        11                  Wales               Wales             Wales
# 11        12               Scotland            Scotland          Scotland
# ...

# %%
db_date = pd.read_csv('C:/Users/juanx/Downloads/forWeb/db_date.csv')
db_date
# Out:
#      date  quote_date  obs_panel     obs       date2       date3       date4  \
# 0       1      198802    35459.0   51065  01-02-1988  01-02-1988  1988-02-01
# 1       2      198803    35240.0   49987  01-03-1988  01-03-1988  1988-03-01
# 2       3      198804    36066.0   51716  01-04-1988  01-04-1988  1988-04-01
# 3       4      198805    35869.0   51209  01-05-1988  01-05-1988  1988-05-01
# 4       5      198806    35811.0   51126  01-06-1988  01-06-1988  1988-06-01
# ..    ...         ...        ...     ...         ...         ...         ...
# 449   452      202509   114123.0  130411  01-09-2025  01-09-2025  2025-09-01
# 450   453      202510   114645.0  131244  01-10-2025  01-10-2025  2025-10-01
# 451   454      202511   115124.0  131778  01-11-2025  01-11-2025  2025-11-01
# 452     7      198808        NaN       0  01-08-1988  01-08-1988  1988-08-01
# 453    13      198902        NaN       0  01-02-1989  01-02-1989  1989-02-01
#
# ...
